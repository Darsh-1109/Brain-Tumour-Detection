# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

# %%
seg = nib.load(r"C:\Users\a21ma\OneDrive\Desktop\Code\Projects\Brain Tumour Detection (IPD)\Dataset 4\BraTS (.nii)\BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData\BraTS20_Training_001\BraTS20_Training_001_seg.nii").get_fdata()
seg.shape
# Out:
# (240, 240, 155)

# %%
t1 = nib.load(r"C:\Users\a21ma\OneDrive\Desktop\Code\Projects\Brain Tumour Detection (IPD)\Dataset 4\BraTS (.nii)\BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData\BraTS20_Training_001\BraTS20_Training_001_t1.nii").get_fdata()
t1.shape

t2 = nib.load(r"C:\Users\a21ma\OneDrive\Desktop\Code\Projects\Brain Tumour Detection (IPD)\Dataset 4\BraTS (.nii)\BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData\BraTS20_Training_001\BraTS20_Training_001_t2.nii").get_fdata()
t2.shape

flair = nib.load(r"C:\Users\a21ma\OneDrive\Desktop\Code\Projects\Brain Tumour Detection (IPD)\Dataset 4\BraTS (.nii)\BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData\BraTS20_Training_001\BraTS20_Training_001_flair.nii").get_fdata()
flair.shape

t1ce = nib.load(r"C:\Users\a21ma\OneDrive\Desktop\Code\Projects\Brain Tumour Detection (IPD)\Dataset 4\BraTS (.nii)\BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData\BraTS20_Training_001\BraTS20_Training_001_t1ce.nii").get_fdata()
t1ce.shape
# Out:
# (240, 240, 155)

# %%
seg = seg[:,:,59]
plt.imshow(seg)
plt.show()

# %%
t1 = t1[:,:,59]
plt.imshow(t1)
plt.show()

# %%
t1ce = t1ce[:,:,59]
plt.imshow(t1ce)
plt.show()

# %%
flair = flair[:,:,59]
plt.imshow(flair)
plt.show()

# %%
t2 = t2[:,:,59]
plt.imshow(t2)
plt.show()
